# %% [markdown]
# # Homework 3
# ## Nhi Le

# %% [markdown]
# ## 1. My dataset

# %%
# Load the package
import numpy as np 
# %matplotlib inline   
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import math
from scipy import stats
import pandas as pd

# %%
#1 My data (n = 4)
my_car = pd.read_csv("~/Desktop/DATA3401/Week 6/mycarsNhiLe.csv")
my_car
# Out:
#                     carname  year  mpg  cyl   disp   hp  drat     wt  qsec  \
# 0  Maserati Quattroporte II  1974   17    8  259.0  523  3.09  4.000  21.5
# 1           Lexus LS 500 F   2018   18    6  345.5  416  2.76  4.905  13.4
# 2                 Honda CRV  2016   28    4  102.9  190  2.64  3.358  15.1
# 3                   Audi A8  2020   19    8  244.0  333  3.20  4.464  13.9
#
#    vs  am  gear  carb  author team
# 0   0   1     5     4  Nhi Le    B
# 1   0   0     8     2  Nhi Le    B
# 2   0   0     5     2  Nhi Le    B
# 3   0   0     8     2  Nhi Le    B

# %% [markdown]
# ##### _ In my data, I choose the 4 cars are randomly from google, and my current car is Honda CRV.
# ##### _ The new column added to the dataframe is year, author and team.
# ##### _ The year column indicated the model year of the car that I choose.
# ##### _ The author column indicated my dataframe for combine with our group in next step.
# ##### _ The team column indicated our team to separate with other team in our class.

# %% [markdown]
# ## 2. Team Data and Processing

# %% [markdown]
# ### Team Data:

# %%
# Team Data
our_car = pd.read_csv("~/Desktop/DATA3401/Week 6/ourcarsB.csv")
our_car.head(n=32)
# Out:
#                                 carname    year    mpg   cyl    disp      hp  \
# 0                     Honda Accord EX-L  2010.0   21.0   6.0  143.65   271.0
# 1                 Lamborghini Aventador  2015.0   11.0  12.0  396.50   740.0
# 2                    Porsche 911 GT3 RS  2019.0   15.0   6.0  243.85   520.0
# 3      Land Rover Range Rover Sport SVR  2016.0   22.0   8.0  304.94   550.0
# 4                        Honda Civic Si  1991.0   24.0   4.0   97.60   108.0
# 5                        Dodge Ram 1500  2008.0   16.0   6.0  225.80   215.0
# 6                          Toyota Supra  2020.0   24.0   6.0  183.00   335.0
# 7                Bentley Continental GT  2020.0   16.0   8.0  244.00   542.0
# 8                    Chevrolet Chevelle  1969.0    7.7   8.0  396.00   375.0
# 9                             Camaro SS  1969.0   12.0   8.0  307.00   200.0
# 10                          Pontiac GTO  1967.0   11.5   8.0  400.00   360.0
# ...

# %% [markdown]
# ### Team Processing to get the combined table:

# %% [markdown]
# ##### _ We create a group me to the discussion and sharing some sources for finding the information about the cars.
# ##### _ Our group using the airtable website to working together on getting our table on the same page.
# ##### _ Our group working on finding the information for the 4 cars that each person choosing.
# ##### _ Also we remind each other and finish the table information through group me.
# ##### _ From Airtable after we finished all the tables of all members, we can download as CSV file for our own work.
# ##### _ All done for our table combined together and we don't have any conflict in our team.
