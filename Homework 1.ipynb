# %% [markdown]
# ## Homework 1 Python Part
# ### Nhi Le - DATA 3401 - 02/06/2020

# %%
# the usual starting block: 
import numpy as np 
# %matplotlib inline   
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import math
from scipy import stats

# %%
ec = np.arange(-2,22)
#1a
a = stats.uniform.cdf(7, 0, 20)
print(a)
# Out:
# 0.35

# %%
xvec = np.arange(0,20.9, 1)
plt.plot(xvec, stats.uniform.pdf(xvec, 0,20), linewidth = 1, c = 'orangered')
#plt.plot(np.array([0,0]), np.array([0, stats.uniform.pdf(0)]), c='orangered', linewidth = .5)

# %%
#1b
b = 1 - stats.uniform.cdf(4, 0, 20)
print(b)
# Out:
# 0.8

# %%
xvec = np.arange(0,20.9, 1)
plt.plot(xvec, stats.uniform.pdf(xvec, 0,20), linewidth = 1, c = 'orangered')

# %%
#1c
c = 1 - stats.uniform.cdf(0, 0, 20)
print(c)
# Out:
# 1.0

# %%
xvec = np.arange(0,20.9, 1)
plt.plot(xvec, stats.uniform.pdf(xvec, 0,20), linewidth = 1, c = 'orangered')

# %%
#2
y = stats.uniform.cdf(17, 0, 20) - stats.uniform.cdf(1, 0, 20)
print(y)
# Out:
# 0.7999999999999999

# %%
xvec = np.arange(0,20.9, 1)
plt.plot(xvec, stats.uniform.pdf(xvec, 0,20), linewidth = 1, c = 'orangered')

# %%
#3
z = (stats.uniform.cdf(1, 0, 20) + (stats.uniform.cdf(15, 0, 20) -  stats.uniform.cdf(12, 0, 20)))*20/15
print(z)
# Out:
# 0.26666666666666666

# %%
xvec = np.arange(0,20.9, 1)
plt.plot(xvec, stats.uniform.pdf(xvec, 0,20), linewidth = 1, c = 'orangered')
