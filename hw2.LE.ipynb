# %%
# the usual starting block
# added pandas
import numpy as np 
# %matplotlib inline   
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import math
from scipy import stats
import pandas as pd

# %% [markdown]
# ## hw2 due Sunday 11:59pm 16 Feb
#
# Submit a notebook in Blackboard like this:  add a JOURNAL ENTRY to the journal hw2 and attach your .ipynb file.  I'll demo in class today.
#
# Consider the data files **file1, file2, file3, file4, file5.xlsx** in the Week 5 folder.
#
# Suppose you've been asked to study these data.   They are from an old database which no longer exists.  You ask for help and five colleagues provide these five files.   The colleagues can be called **colleague1, colleague2, etc.**, but it will make a better story if you give them **real names**.
#
# You have to decide which file(s) to use for your study.  The study itself is not part of this hw.
#
# ### 1.  Import file1, file2, etc. as data.frames.
# Name the data.frames dat1, dat2, etc.  We did this part on Tuesday.

# %%
dat1 = pd.read_csv("file1.dms")
dat2 = pd.read_csv("file2.dms", sep = ';')
dat3 = pd.read_csv("file3.dms", sep = '\t')
dat4 = pd.read_csv("file4.dms", sep =' ')
dat5 = pd.read_excel("file5.xlsx", sheet_name = 1)

# %%
# Import CSV mtcars
originalfile = pd.read_csv('https://gist.githubusercontent.com/ZeccaLehn/4e06d2575eb9589dbe8c365d61cb056c/raw/64f1660f38ef523b2a1a13be77b002b98665cdfe/mtcars.csv')
# Edit element of column header
originalfile.rename(columns={'Unnamed: 0':'brand'}, inplace=True)
originalfile
# Out:
#                   brand   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
# take a look at each file
print(dat1)
print(dat2)
print(dat3)
print(dat4)
print(dat5)
# Out:
#                 carname   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#Summary statistics for numerical columns
test1 = dat1.describe()
print("Data 1 is:")
print(test1)
test2 = dat2.describe()
print("Data 2 is:")
print(test2)
test3 = dat3.describe()
print("Data 3 is:")
print(test3)
test4 = dat4.describe()
print("Data 4 is:")
print(test4)
test5 = dat5.describe()
print("Data 5 is:")
print(test5)
# Out:
# Data 1 is:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  233.846875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  126.349224   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  350.250000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# ...

# %% [markdown]
# ### 2.  Decide which file or files to use for your study.
# That means identifying which (if any) files are "correct", and which (if any) are flawed. If two files are identical, that is worth pointing out.  If a file can be ignored, that should be noted.
#
# **You can work this out with your eyes, but use python to show exactly how you are making your decisions.  The data.frame commands in Ch 3 will help with this part.  You'll have to add cells to this notebook.  Markdown cells for  your voice and code cells to back up your conclusions.  **

# %%
compare1 = dat1.mean()
min1 = dat1.min()
max1 = dat1.max()

print("Data 1 is:")
print(compare1)
print(min1)
print(max1)
# Out:
# Data 1 is:
# mpg      20.090625
# cyl       6.187500
# disp    233.846875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64
# carname    AMC Javelin
# mpg               10.4
# cyl                  4
# disp              71.1
# hp                  52
# drat              2.76
# wt               1.513
# qsec              14.5
# vs                   0
# am                   0
# gear                 3
# carb                 1
# dtype: object
# carname    Volvo 142E
# mpg              33.9
# cyl                 8
# disp              472
# hp                335
# drat             4.93
# wt              5.424
# qsec             22.9
# vs                  1
# am                  1
# gear                5
# carb                8
# dtype: object

# %%
compare4 = dat4.mean()
min4 = dat4.min()
max4 = dat4.max()

print("Data 4 is:")
print(compare4)
print(min4)
print(max4)
# Out:
# Data 4 is:
# mpg      38.528125
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64
# carname    AMC Javelin
# mpg               10.4
# cyl                  4
# disp              71.1
# hp                  52
# drat              2.76
# wt               1.513
# qsec              14.5
# vs                   0
# am                   0
# gear                 3
# carb                 1
# dtype: object
# carname    Volvo 142E
# mpg             330.4
# cyl                 8
# disp              472
# hp                335
# drat             4.93
# wt              5.424
# qsec             22.9
# vs                  1
# am                  1
# gear                5
# carb                8
# dtype: object

# %%
compare2 = dat2.mean()
min2 = dat2.min()
max2 = dat2.max()

print("Data 2 is:")
print(compare2)
print(min2)
print(max2)
# Out:
# Data 2 is:
# mpg      20.309091
# cyl       6.121212
# disp    226.124242
# hp      144.242424
# drat      3.611212
# wt        3.178394
# qsec     17.882121
# vs        0.454545
# am        0.424242
# gear      3.696970
# carb      2.757576
# dtype: float64
# carname    AMC Javelin
# mpg               10.4
# cyl                  4
# disp              71.1
# hp                  52
# drat              2.76
# wt               1.513
# qsec              14.5
# vs                   0
# am                   0
# gear                 3
# carb                 1
# dtype: object
# carname    Volvo 142E
# mpg              33.9
# cyl                 8
# disp              472
# hp                335
# drat             4.93
# wt              5.424
# qsec             22.9
# vs                  1
# am                  1
# gear                5
# carb                8
# dtype: object

# %%
compare3 = dat3.mean()
min3 = dat3.min()
max3 = dat3.max()

print("Data 3 is:")
print(compare3)
print(min3)
print(max3)
# Out:
# Data 3 is:
# mpg      19.858065
# cyl       6.258065
# disp    235.616129
# hp      149.290323
# drat      3.580968
# wt        3.258613
# qsec     17.814839
# vs        0.419355
# am        0.387097
# gear      3.677419
# carb      2.870968
# dtype: float64
# carname    AMC Javelin
# mpg               10.4
# cyl                  4
# disp              71.1
# hp                  52
# drat              2.76
# wt               1.513
# qsec              14.5
# vs                   0
# am                   0
# gear                 3
# carb                 1
# dtype: object
# carname    Volvo 142E
# mpg              33.9
# cyl                 8
# disp              472
# hp                335
# drat             4.93
# wt              5.424
# qsec             22.9
# vs                  1
# am                  1
# gear                5
# carb                8
# dtype: object

# %%
compare5 = dat5.mean()
min5 = dat5.min()
max5 = dat5.max()

print("Data 5 is:")
print(compare5)
print(min5)
print(max5)
# Out:
# Data 5 is:
# mpg      19.858065
# cyl       6.129032
# disp    229.267742
# hp      145.612903
# drat      3.613548
# wt        3.200710
# qsec     17.856774
# vs        0.451613
# am        0.419355
# gear      3.709677
# carb      2.806452
# dtype: float64
# carname    AMC Javelin
# mpg               10.4
# cyl                  4
# disp              71.1
# hp                  52
# drat              2.76
# wt               1.513
# qsec              14.5
# vs                   0
# am                   0
# gear                 3
# carb                 1
# dtype: object
# carname    Volvo 142E
# mpg              32.4
# cyl                 8
# disp              472
# hp                335
# drat             4.93
# wt              5.424
# qsec             22.9
# vs                  1
# am                  1
# gear                5
# carb                8
# dtype: object

# %% [markdown]
# ##### _ The data in file 4 have the most error in data set because the carname Volvo 142E have the most significant different mpg at 330.4. The car cannot go up to 330.4 miles per galon gas.

# %%
set_diff = pd.concat([dat2,dat3]).drop_duplicates(keep = False)
set_diff
# Out:
#       carname   mpg  cyl   disp  hp  drat    wt   qsec  vs  am  gear  carb
# 2  Datsun 710  22.8    4  108.0  93  3.85  2.32  18.66   1   1     4     1
# 2  Datsun 710  22.8    4  108.0  93  3.85  2.32  18.61   1   1     4     1

# %% [markdown]
# ##### _ The data in file 2 and file 3 are mostly the same

# %%
set_diff = pd.concat([dat1,dat2]).drop_duplicates(keep = False)
set_diff
# Out:
#         carname   mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  carb
# 2    Datsun 710  22.8    4  108.0   93  3.85  2.32  18.61   1   1     4     1
# 13  Merc 450SLC  15.2    8  375.8  180  3.07  3.78  18.00   0   0     3     3
# 2    Datsun 710  22.8    4  108.0   93  3.85  2.32  18.66   1   1     4     1
# 13  Merc 450SLC  15.2    8  275.8  180  3.07  3.78  18.00   0   0     3     3

# %%
set_diff = pd.concat([dat1,dat3]).drop_duplicates(keep = False)
set_diff
# Out:
#         carname   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  carb
# 13  Merc 450SLC  15.2    8  375.8  180  3.07  3.780  18.0   0   0     3     3
# 25    Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.9   1   1     4     1
# 13  Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.0   0   0     3     3

# %%
set_diff = pd.concat([dat1,dat4]).drop_duplicates(keep = False)
set_diff
# Out:
#            carname    mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 13     Merc 450SLC   15.2    8  375.8  180  3.07  3.780  18.0   0   0     3
# 19  Toyota Corolla   33.9    4   71.1   65  4.22  1.835  19.9   1   1     4
# 27    Lotus Europa   30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L   15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino   19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora   15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 13     Merc 450SLC   15.2    8  275.8  180  3.07  3.780  18.0   0   0     3
# 19  Toyota Corolla   23.9    4   71.1   65  4.22  1.835  19.9   1   1     4
# 27    Lotus Europa  330.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  115.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  119.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# ...

# %%
set_diff = pd.concat([dat1,dat5]).drop_duplicates(keep = False)
set_diff
# Out:
#                 carname   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  375.8  180  3.07  3.780  18.00   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 12          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 18       Toyota Corolla  23.9    4   71.1   65  4.22  1.835  19.90   1   1
# 26         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
#
#     gear  carb
# 12     3     3
# 13     3     3
# 15     3     4
# 19     4     1
# 27     5     2
# 12     3     3
# 14     3     4
# 18     4     1
# 26     5     2

# %% [markdown]
# ##### _ The data in file 1 are correct.
# ##### _ The data in file 2 are duplicate for Fiat X1-9 and columns difference compare to file 1 at rows 2 and 13.
# ##### _ The data in file 3 are missing for Fiat X1-9 and columns difference compare to file 1 at row 13.
# ##### _ The data in file 4 have 6 lines contain the wrong record number data.
# ##### _ The data in file 5 are missing for Merc 450SE, and contain 4 lines have the wrong record number data.

# %% [markdown]
# ### 3.  Include images as appropriate.
# You decide what appropriate is.  Definitely include images of your favorite and least favorite car in the dataset.  There are two markdown cells below that show how to insert an image.  Double click the image to the markdown command for the image.  Your images will be cars, not Star Wars.

# %% [markdown]
# ##### My most favorite car in the data set is Maserati Bora

# %% [markdown]
# ![Maserati_Bora_1974.jpg](attachment:Maserati_Bora_1974.jpg)

# %% [markdown]
# ##### My least favorite car in the data set is Mazda RX4 Wag

# %% [markdown]
# ![Mazda%20RX4%20Wag%201974.jpg](attachment:Mazda%20RX4%20Wag%201974.jpg)

# %% [markdown]
# ### 4.  Try to discover something about the provenance or pedigree of these data.
# It's a google question.  What is the original source of these data?

# %% [markdown]
# #### _The original source of these data come from mtcars parkage in R and Python.
# #### _mtcars data comes from the 1974 Motor Trend magazine.
# #### _The data includes fuel consumption data, and ten aspects of car design for then-current car models.
